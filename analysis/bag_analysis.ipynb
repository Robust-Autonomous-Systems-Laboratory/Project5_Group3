# %% [markdown]
# # Project 5 Introduction to Robotics
# ## Anders Smitterberg Progress Munoriarwa
# ### In this project we determine the intrinsic parameters of a simple laser rangefinder on a turtlebot3.
